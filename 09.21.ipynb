# %%
name= "홍길동"
age = 30
f"나의 이름은 {name}입니다. 나이는 {age}입니다."
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
f"내년이면 나이가 {age+1}입니다"
# Out:
# '내년이면 나이가 31입니다'

# %%
d = {'name' : '홍길동', 'age':30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
d2={1:"홍길동", 2:30}
d2[2]
# Out:
# 30

# %%
a= "hobby"
a.count('b')
# Out:
# 2

# %%
",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
a= 'hi'
a.upper()
# Out:
# 'HI'

# %%
a= 'hi'
a.lower()
# Out:
# 'hi'

# %%
a= " hi "
a.lstrip()
# Out:
# 'hi '

# %%
a= 'hi'
a.rstrip()
# Out:
# 'hi'

# %%
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
 a = "Life is too short"
 a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 3, 1, 2, 3]
a.remove(3)
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a = [1,1,1,1,12,3,1]
a.count(1)
# Out:
# 5

# %%
 a = [1,2,3]
a.extend([4,5])
a
b = [6, 7]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
assig.  0 통계량 조사
1 통계량 입력 (국가 ? , 인구? gdp? 기대수명? 
2 통계량 조회
3 통계량 수정
4 통계량 삭제

# %%
t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))

# %%
t1 = (1, 2, 'a', 'b')
t1[0]='c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-28cca4cf0c10> in <module>
#       1 t1 = (1, 2, 'a', 'b')
# ----> 2 t1[0]='c'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = [1,2,'a','b']
del t1[0]

# %%
print(t1)
# Out:
# [2, 'a', 'b']

# %%
t1[0] = 'c'
