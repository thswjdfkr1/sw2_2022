# %%
#클래스 활용 - 국가정보(입력 조회 수정 삭제 종료)
#ex) "rectangle" 클래스 정의(가로길이, 세로길이를 매게변수0
#rec1 = rectangle(10,5)
rec2 = rectangle(5,7)
ex) "country"클래스 정의(명칭,인구, GDP)
명칭: name, 인구:pop,GDP: gdp 
country1=country("korea",50000,100000)
counry2=country2("japan",30000,100000)
country3=country3

class country:
  def_init_(self,)
# Out:
#   File "<ipython-input-2-1cca1afcf6b0>", line 5
#     ex) "country"클래스 정의(명칭,인구, GDP)
#       ^
# SyntaxError: unmatched ')'

# %%
class country:
  def __init__(a, u_name, u_pop, u_gdp):
    a.name = u_name
    a.pop = u_pop
    a.gdp = u_gdp

# %%
#def에 값을 저장해도되고 cn1에서 입력해도되고
cn1 = country("korea", 5000, 100)
cn2 = country("japan", 10000, 100)

# %%
print(cn1. name)
print(cn1.pop)
print(cn2.name)
print(cn2.pop)
# Out:
# korea
# 5000
# japan
# 10000

# %%
class country2:
 #cn_code = ["KR","JP"]
 cn_code = []
 #cn_pop = {"KR":5000,"JP":10000}
 cn_pop = {}
 cn_z = {}
 def __init__(self, u_code, u_name, u_pop, u_z, u_gdp=-1):
    self.code = u_code
    self.name = u_name
    self.pop = u_pop
    self.z = u_z
    self.gdp= u_gdp
   
    country2.cn_pop[self.code] = self.pop
    
    country2.cn_code.append(self.code)
    country2.cn_z[self.code]=self.z

# %%
#한국 일본 정보 입력
cn1 = country2("KR", "Korea","한국", 5000)
cn2 = country2("JP","Japan","일본",10000)

# %%
print(cn1.code)
print(cn1.pop)
print(cn1.z)
# Out:
# KR
# 한국
# 5000

# %%
print(country2.cn_code)
print(country2.cn_pop)
print(cn1.cn_code)
#print(country.code)
# Out:
# ['KR', 'JP']
# {'KR': '한국', 'JP': '일본'}
# ['KR', 'JP']

# %%
#국가 코드 먼저알려주기
print(country2.cn_code)
#사용자에게 기준 국가코드 입력요청 ㅣ KR
a = input("기준 국가코드를 입력해 주세요:")
#사용자에게 비교할 국가코드입력 요청 ; JP
b= input("비교할 국가코드를 입력해주세요:")
#비교해서 알려주기
print("기준 국가코드 %s의 인구는 %d입니다."%(a, country2.cn_pop[a]))
print("비교 국가코드 %s의 인구는 %d입니다."%(b, country2.cn_pop[b]))
# Out:
# ['KR', 'KR', 'JP', 'JP']

# %%
test_pop= {}
test_pop["KR"] = 5000
test_pop["JP"] = 10000

# %%
print(test_pop)
# Out:
# {'KR': 5000, 'JP': 10000}
