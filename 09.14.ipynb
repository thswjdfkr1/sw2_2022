# %%
multiline = """
Life is too short, 
You need python
"""

# %%
print(multiline)
# Out:
# Life is too short,
# You need python

# %%
head = "Python"
tail = " is fun!"

# %%
head + tail
# Out:
# 'Python is fun!'

# %%
동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 무궁화 삼천리 화려가앙산 대한사람 대한으로 길이 보전하세

# %%
남산 위에 저 소나무 철갑을 두른 듯 바람서리 불변함은 우리 기상일세 무궁화 삼천리 화려가앙산 대한사람 대한으로 길이 보전하세

# %%
가을 하늘 공활한데 높고 구름없이 밝은 달은 우리 가슴 일편 단심일세 무궁화 삼천리 화려가앙산 대한사람 대한으로 길이 보전하세

# %%
이 기상과 이 맘으로 충성을 다하여 괴로우나 즐거우나 나라 사랑하세 무궁화 삼천리 화려가앙산 대한사람 대한으로 길이 보전하세

# %%
a = "Life is too short, You need Python"

# %%
len(a)
# Out:
# 1

# %%
a[-1]
# Out:
# 'n'

# %%
a[0:4]
# Out:
# 'Life'

# %%
a[23:27]
# Out:
# 'need'

# %%
"%-10sjane." % 'hi'
# Out:
# 'hi        jane.'

# %%
 "%10.4f" % 3.42134234
# Out:
# '    3.4213'

# %%
"I eat {0} apples".format(3)
# Out:
# 'I eat 3 apples'

# %%
"I eat {0} apples".format("five")
# Out:
# 'I eat five apples'

# %%
number = 10
day = "three"
"I ate {0} apples. so I was sick for {1} days.".format(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"I ate {day} apples. so I was sick for {number} days.".format(number=10, day=3)
# Out:
# 'I ate 3 apples. so I was sick for 10 days.'

# %%
number = 10
day = "three"

# %%
number = 10
day = "three"
"I ate {1} apples. so I was sick for {0} days.".format(day, 3)
# Out:
# 'I ate 3 apples. so I was sick for three days.'
