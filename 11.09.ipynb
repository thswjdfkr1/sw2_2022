# %%
객체 지행 프로그래밍(오브젝트 오리엔티드 프로그래밍; OOP))
구조체 -> 클래스
성명
나이
생일
출신학교
생일
연봉
ㅡㅡㅡㅡ
func1
func2

# %%
class FourCal:
   pass

a=FourCal()

# %%
class FourCal:
 def setdata(self, first, second):
  self.first = first
  self.second = second
 def add(self):
  result = self.first + self.second
  return result

 name = "kim"
 age = 25

# %%
c= FourCal()
print(c.name)
print(c.age)
# Out:
# kim
# 25

# %%
a = FourCal()
a.setdata(4, 2)
#print(a.first)
#print(a.second)
print(a.add())
# Out:
# 6

# %%
class player():
  def __init__(self, n="uknown", a=-1):
    self.name = n
    self.age = a

# %%
a=player("kim", 25)

# %%
print(a.age)
print(a.name)
# Out:
# 25
# kim

# %%
b=player()

# %%
print(b.name)
print(b.age)
# Out:
# uknown
# -1

# %%
class MoreFourCal(FourCal):
  def pow(self,v1,v2):
    result = self.first ** self.second
    return result

# %%
class player2(player):
  def p_info(self):
    print("선수이름은 %s입니다."%self.name)
    print("선수나이는 %d입니다."%self.age)

# %%
c=player2("Son",31)
print(c.p_info())
# Out:
# 선수이름은 Son입니다.
# 선수나이는 31입니다.
# None

# %%
value = FourCal()
